# %%
from __future__ import print_function

import datetime
import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
### Get Creds  ###
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/calendar']

credFile = "client_secret_140900915869-fhu0jhf0lavfak0mugsm1shao5kiqjnt.apps.googleusercontent.com.json"
creds = None
emailCalendar = "mlg7rian@gmail.com"
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            credFile, SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())

# %%
### Get Events ###
try:
    service = build('calendar', 'v3', credentials=creds)

    # Call the Calendar API
    now = datetime.datetime.utcnow().isoformat() + 'Z'  # 'Z' indicates UTC time
    print('Getting the upcoming 10 events')
    events_result = service.events().list(calendarId=emailCalendar, timeMin=now,
                                            maxResults=10, singleEvents=True,
                                            orderBy='startTime').execute()
    events = events_result.get('items', [])

    if not events:
        print('No upcoming events found.')

    # Prints the start and name of the next 10 events
    for event in events:
        start = event['start'].get('dateTime', event['start'].get('date'))
        print(start, event['summary'])
        try:
            print(event['description'])
        except:
            print()
except HttpError as error:
    print('An error occurred: %s' % error)
# Out:
# Getting the upcoming 10 events
# 2024-01-23T08:00:00+08:00 Art Festival
#
# 2024-03-01 Make Teeth Appointment
#
# 2024-03-22T12:30:00+08:00 West Birthday
#
# 2024-08-02 Faizul Birthday 🎂
#
# 2024-08-28 Amirul Birthday
#
# 2024-09-01 Make Teeth Appointment
#
# 2024-12-30 Has birthday
#
# 2025-03-01 Make Teeth Appointment
#
# 2025-03-22T12:30:00+08:00 West Birthday
#
# 2025-08-02 Faizul Birthday 🎂

# %%
def genDateFormat(year, month, day):
    end_date = f'{year}{month:02d}{day:02d}T235959Z'
    return end_date
end_date = genDateFormat(2024, 2, 9)
ex_date = genDateFormat(2024, 1, 1)

# %%
### Adding Event ###
def addEvent(eventName, eventDate, endReDate, startTime, endTime, colorId):
  event = {
    'summary': eventName,
    'description': '',
    'start': {
      'dateTime': f'{eventDate}T{startTime}',
      'timeZone': 'Asia/Kuching',
    },
    'end': {
      'dateTime': f'{eventDate}T{endTime}',
      'timeZone': 'Asia/Kuching',
    },
    'recurrence': [
      f'RRULE:FREQ=WEEKLY;UNTIL={endReDate}'
    ],
    'recurrenceExclusion': [
      ex_date,  # Specify the date you want to exclude
    ],
    'reminders': {
      'useDefault': False,
      'overrides': [
        {'method': 'popup', 'minutes': 30},
        {'method': 'popup', 'minutes': 10},
        {'method': 'popup', 'minutes': 5},
      ],
    },
    'colorId': f'{colorId}',
  }
  try:
    service = build('calendar', 'v3', credentials=creds)
    event = service.events().insert(calendarId='primary', body=event).execute()
    print ('Event created:', event.get('htmlLink'))
  except HttpError as error:
      print('An error occurred: %s' % error)

# %%
datetime.datetime("2023.10.30").isoformat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 datetime.datetime("2023.10.30").isoformat()
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# colorId:
#
# "1" - Lavender (Y9 STEAM)
#
# "2" - Sage (Y8 ICT)
#
# "3" - Grape  (Y10 DT)
#
# "4" - Flamingo
#
# "5" - Banana (Meeting, Assembly, PSHE)
#
# "6" - Tangerine (Y7 STEAM)
#
# "7" - Peacock (Y9 ICT)
#
# "8" - Graphite (Y11 ICT)
#
# "9" - Blueberry (Y10 CS)
#
# "10" - Basil (Y8 STEAM)
#
# "11" - Tomato (Y7 ICT)

# %%
moikeClass = [
    #Monday
    ["Y10_DT","2024-1-1","08:00:00", "09:00:00", "3"],
    ["Y7_DL","2024-1-1","09:00:00", "10:00:00", "11"], 
    ["Y9_DL","2024-1-1","11:30:00", "12:30:00", "7"], 
    ["Y11_ICT","2024-1-1","12:30:00", "14:00:00", "8"], 
    ["Meeting","2024-1-1","15:00:00", "16:00:00", "5"], 
    #Tues
    ["NC","2024-1-2", "08:00:00", "09:00:00"],
    ["Y7_DL","2024-1-2","09:00:00", "10:00:00", "11"], 
    ["Y8_STEAM","2024-1-2","10:30:00", "11:30:00", "10"], 
    ["Y10_CS","2024-1-2","11:30:00", "13:00:00", "9"], 
    ["Y8_DL","2024-1-2","14:00:00", "15:00:00", "2"],
    #Wed
    ["Y8_DL","2024-1-3","09:00:00", "10:00:00", "2"],
    ["Y7_STEAM","2024-1-3","10:30:00", "11:30:00", "6"],
    ["Canteen Duty","2024-1-3","13:00:00", "13:20:00", "5"],
    ["Y10_CS","2024-1-3","13:30:00", "15:00:00", "9"],
    ["Maker's Club","2024-1-3","15:00:00", "16:00:00", "4"],
    #Thu
    ["Y11_ICT","2024-1-4","08:00:00", "09:00:00", "8"],
    ["Y10_DT","2024-1-4","09:00:00", "10:00:00", "3"],
    ["Y9_STEAM","2024-1-4","10:30:00", "11:30:00", "1"],
    ["Y8_STEAM","2024-1-4","12:30:00", "14:00:00", "10"],
    ["Y9_DL","2024-1-4","14:00:00", "15:00:00", "7"],
    ["Drone Club","2024-1-4","15:00:00", "16:00:00", "4"],
    #Fri
    ["Y11_ICT","2024-1-5","09:00:00", "10:00:00", "8"],
    ["Y10_DT","2024-1-5","10:30:00", "11:30:00", "3"],
    ["Y9_STEAM","2024-1-5","11:30:00", "12:30:00", "1"],
    ["Assembly","2024-1-5","12:30:00", "13:00:00", "5"],
    ["PSHE","2024-1-5","13:30:00", "14:10:00", "5"],
    ["Y7_STEAM","2024-1-5","14:10:00", "15:00:00", "6"],
]
endDate = genDateFormat(2024, 2, 9)
for subject in moikeClass:
    if subject[0] != "NC":
        addEvent(subject[0], subject[1], endDate, subject[2], subject[3], subject[4])
# Out:
# Event created: https://www.google.com/calendar/event?eid=aWNhcm9xY2swdG43azhva3M4cjJyM2h1NTRfMjAyNDAxMDFUMDAwMDAwWiBtbGc3cmlhbkBt
# Event created: https://www.google.com/calendar/event?eid=dmEycnIyYzZhMWY4c3FtbTNhNmtiaHRiZjRfMjAyNDAxMDFUMDEwMDAwWiBtbGc3cmlhbkBt
# Event created: https://www.google.com/calendar/event?eid=czBpbTVnbXFwY2Q0YzIxODR2MTdmM29hbmtfMjAyNDAxMDFUMDMzMDAwWiBtbGc3cmlhbkBt
# Event created: https://www.google.com/calendar/event?eid=YnRoYXMwNzgycnRwbnVvODg0djYybHBwa2NfMjAyNDAxMDFUMDQzMDAwWiBtbGc3cmlhbkBt
# Event created: https://www.google.com/calendar/event?eid=YTNzaWVnczlxZWd1OWM1YjlrMzFybnN1aG9fMjAyNDAxMDFUMDcwMDAwWiBtbGc3cmlhbkBt
# Event created: https://www.google.com/calendar/event?eid=MWN1aW4zYnNpYmc1YjEyYmxwMXFkYzdoMGtfMjAyNDAxMDJUMDEwMDAwWiBtbGc3cmlhbkBt
# Event created: https://www.google.com/calendar/event?eid=MzY3bmczNGRuMjk2a2hjMnZmc3F2b2s2aGdfMjAyNDAxMDJUMDIzMDAwWiBtbGc3cmlhbkBt
# ...

# %%
### Adding Event ###
startDate = datetime.datetime(2023, 10, 23, 8, 0, 0).isoformat()
endDate = genDateFormat(2023, 12, 8)

event = {
  'summary': "Test",
  'description': '',
  'start': {
    'dateTime': '2023-12-11T08:00:00',
    'timeZone': 'Asia/Kuching',
  },
  'end': {
    'dateTime': '2023-12-11T09:00:00',,
    'timeZone': 'Asia/Kuching',
  },
  # 'recurrence': [
  #   f'RRULE:FREQ=WEEKLY;UNTIL={endDate}'
  # ],
  'reminders': {
    'useDefault': False,
    'overrides': [
      {'method': 'popup', 'minutes': 30},
      {'method': 'popup', 'minutes': 10},
      {'method': 'popup', 'minutes': 5},
    ],
  },
  'colorId': '3',
}
try:
  service = build('calendar', 'v3', credentials=creds)
  event = service.events().insert(calendarId='primary', body=event).execute()
  print ('Event created:', event.get('htmlLink'))
except HttpError as error:
    print('An error occurred: %s' % error)
